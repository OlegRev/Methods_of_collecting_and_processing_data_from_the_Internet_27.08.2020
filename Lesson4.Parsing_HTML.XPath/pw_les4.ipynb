# %% [markdown]
# Написать приложение,
# которое собирает основные новости с сайтов:
#
#     mail.ru, lenta.ru, yandex-новости.
# Для парсинга использовать XPath.
# Структура данных должна содержать:
#
#     название источника;
#     наименование новости;
#     ссылку на новость;
#     дата публикации.
#
# Сложить все в базу данных

# %%
from pprint import pprint
from lxml import html
import requests
import datetime
from pymongo import MongoClient, errors

# %%
def get_news(website: str, rubric: str):
    """
    website == 'mail.ru' ,
               'lenta.ru',
               'yandex.ru'
              
    rubric == 'politics',
              'economics',
              'society',
              'incident'
    """
    rubric_dict = {'politics': 0, 'economics': 1, 'society': 2, 'incident': 3}
    headers = {'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36'}
    links_for_news = {'mail.ru' : {'main_link': 'https://news.mail.ru',
                                   'second_link': ['/politics/', '/economics/', '/society/', '/incident/']},
                      'lenta.ru': {'main_link': 'https://lenta.ru',
                                   'second_link': ['/rubrics/world/politic/', '/rubrics/economics/', '/rubrics/world/society/', '/rubrics/world/accident/']},
                      'yandex.ru': {'main_link': 'https://yandex.ru/news',
                                    'second_link': ['/rubric/politics', '/rubric/business', '/rubric/society', '/rubric/incident']}
                     }

    news_link_xpath = {'mail.ru' : "//div[@data-module='TrackBlocks']//a[contains(@href, 'news.mail.ru') and not(contains(@href, 'comments'))]/@href",
                       'lenta.ru': "//section[contains(@class, 'rubric')]//a[@href and not(contains(@class, 'banner-pay'))]/@href",
                       'yandex.ru': "//article[contains(@class, 'news-card')]//a[@class='news-card__link']/@href"}
    news_name_xpath = {'mail.ru' : "//div[@data-module='TrackBlocks']/div[contains(@class,'hdr') and contains(@class,'title')]//h1",
                       'lenta.ru': "//div[contains(@class,'b-topic-layout')]//h1",
                       'yandex.ru': "//article[contains(@class, 'news-card')]//a[@class='news-card__link']/h2"}
    date_of_publication_xpath = {'mail.ru' : "//div[@data-module='TrackBlocks']/div[contains(@class,'breadcrumbs')]//span[@datetime]/@datetime",
                                 'lenta.ru': "//div[contains(@class,'b-topic-layout')]//time[@class='g-date']/@datetime",
                                 'yandex.ru': "//article[contains(@class, 'news-card')]//span[@class='mg-card-source__time']"}                           
    news_source_link_xpath = {'mail.ru' : "//div[@data-module='TrackBlocks']/div[contains(@class,'breadcrumbs')]//a[@target]/@href",
                              'lenta.ru': "https://lenta.ru",
                              'yandex.ru': "//article[contains(@class, 'news-card')]//div[contains(@class, 'news-card__source')]/span/a[@href]/@href"}
    news_source_name_xpath = {'mail.ru' : "//div[@data-module='TrackBlocks']/div[contains(@class,'breadcrumbs')]//a[@target]/span[@class='link__text']",
                              'lenta.ru': "Lenta.ru («Лента.ру»)",
                              'yandex.ru': "//article[contains(@class, 'news-card')]//div[contains(@class, 'news-card__source')]//a/text()"}
    
    link = links_for_news[website]['main_link'] + links_for_news[website]['second_link'][rubric_dict[rubric]]
    request = requests.get(link, headers=headers)
    root_dom = html.fromstring(request.text)
    news_links = root_dom.xpath(news_link_xpath[website])
    news_data = []
    if website == 'yandex.ru':
        news_name = root_dom.xpath(news_name_xpath[website])
        date_of_publication = root_dom.xpath(date_of_publication_xpath[website])
        news_source_link = root_dom.xpath(news_source_link_xpath[website])
        news_source_name = root_dom.xpath(news_source_name_xpath[website])
        for link_item in  range(len(news_links)):
            news = {}
            news['news_link'] = news_links[link_item]
            news['news_name'] = news_name[link_item].text
            __date_news = datetime.date.today()
            news['date_of_publication'] =   [f'{str(__date_news)} {date_of_publication[link_item].text}']
            request = requests.get(news_source_link[link_item], headers=headers)
            root_dom = html.fromstring(request.text)
            news['news_source_link'] = root_dom.xpath("//a[@class='news-story__subtitle']/@href")[0]
            news['news_source_name'] = news_source_name[link_item]
            news_data.append(news)
        return news_data
    
    for link_item in set(news_links):
        news = {}
        if website == 'lenta.ru':
            link_item = links_for_news[website]['main_link'] + link_item
        request = requests.get(link_item, headers=headers)
        root_dom = html.fromstring(request.text)
        
        news_name = root_dom.xpath(news_name_xpath[website])
        date_of_publication = root_dom.xpath(date_of_publication_xpath[website])
        
        news['news_link'] = link_item
        news['date_of_publication'] = date_of_publication
        if website == 'mail.ru':
            news['news_name'] = news_name[0].text
            
            news_source_link = root_dom.xpath(news_source_link_xpath[website])
            news_source_name = root_dom.xpath(news_source_name_xpath[website])
            news['news_source_link'] = news_source_link[0]
            news['news_source_name'] = news_source_name[0].text
        elif website == 'lenta.ru':        
            news['news_name'] = news_name[0].text.replace('\xa0', ' ')  
            news['news_source_link'] = news_source_link_xpath[website]
            news['news_source_name'] = news_source_name_xpath[website]
        
        news_data.append(news)
        
    return news_data

# %%
mail_politics_news = get_news('mail.ru', rubric='politics')
mail_politics_news
# Out:
# [{'news_link': 'https://news.mail.ru/politics/43337955/',
#   'date_of_publication': ['2020-09-12T22:15:50+03:00'],
#   'news_name': 'Как прошел второй день досрочного голосования в Ленобласти',
#   'news_source_link': 'https://ivbg.ru/',
#   'news_source_name': 'ivbg.ru'},
#  {'news_link': 'https://news.mail.ru/politics/43345991/',
#   'date_of_publication': ['2020-09-13T18:12:19+03:00'],
#   'news_name': 'Основная масса протестующих в Минске собралась в районе Дрозды',
#   'news_source_link': 'http://www.tass.ru/',
#   'news_source_name': 'ТАСС'},
#  {'news_link': 'https://news.mail.ru/politics/43345119/',
#   'date_of_publication': ['2020-09-13T16:18:46+03:00'],
#   'news_name': 'Канцлер Австрии сообщил о начале второй волны коронавируса в стране',
#   'news_source_link': 'http://www.kommersant.ru',
#   'news_source_name': 'Коммерсантъ'},
#  {'news_link': 'https://news.mail.ru/politics/43328260/',
#   'date_of_publication': ['2020-09-11T17:27:40+03:00'],
#   'news_name': 'Правительство переименовало Минкомсвязи',
#   'news_source_link': 'http://www.interfax.ru/',
#   'news_source_name': 'Интерфакс'},
#  {'news_link': 'https://news.mail.ru/politics/43331014/',
#   'date_of_publication': ['2020-09-11T21:44:35+03:00'],
#   'news_name': 'Козак рассказал об итогах встречи советников «нормандской четверки»',
#   'news_source_link': 'http://www.ria.ru',
#   'news_source_name': 'РИА Новости'},
#  {'news_link': 'https://news.mail.ru/politics/43343261/',
#   'date_of_publication': ['2020-09-13T12:47:53+03:00'],
#   'news_name': 'Названы регионы России с самой высокой и низкой явкой на выборах',
#   'news_source_link': 'https://lenta.ru/',
#   'news_source_name': 'Lenta.Ru'},
#  {'news_link': 'https://news.mail.ru/politics/43343286/',
#   'date_of_publication': ['2020-09-13T14:31:09+03:00'],
#   'news_name': 'Видео: Александр Дрозденко принял участие в едином дне голосования',
#   'news_source_link': 'https://ivbg.ru/',
#   'news_source_name': 'ivbg.ru'},
#  {'news_link': 'https://news.mail.ru/politics/43342478/',
#   'date_of_publication': ['2020-09-13T11:18:56+03:00'],
#   'news_name': 'Губернатором НАО стал Юрий Бездудный',
#   'news_source_link': 'http://www.kommersant.ru',
#   'news_source_name': 'Коммерсантъ'},
#  {'news_link': 'https://news.mail.ru/politics/43344832/',
#   'date_of_publication': ['2020-09-13T15:44:24+03:00'],
#   'news_name': 'МВД Белоруссии сообщило о задержании 250 человек в Минске',
#   'news_source_link': 'http://www.ria.ru',
#   'news_source_name': 'РИА Новости'},
#  {'news_link': 'https://news.mail.ru/politics/43341701/',
#   'date_of_publication': ['2020-09-13T10:04:08+03:00'],
#   'news_name': 'В России проходит единый день голосования',
#   'news_source_link': 'https://rns.online/',
#   'news_source_name': 'RNS'},
#  {'news_link': 'https://news.mail.ru/politics/43335429/',
#   'date_of_publication': ['2020-09-12T13:06:19+03:00'],
#   'news_name': 'Белорусскую оппозиционерку Колесникову перевели в следственную тюрьму',
#   'news_source_link': 'https://life.ru/',
#   'news_source_name': 'Life.ru'},
#  {'news_link': 'https://news.mail.ru/politics/43343695/',
#   'date_of_publication': ['2020-09-13T13:32:46+03:00'],
#   'news_name': 'Памфилова заявила о возможности для ЦИК «поучиться» у Казахстана',
#   'news_source_link': 'https://www.rbc.ru/',
#   'news_source_name': 'РБК'},
#  {'news_link': 'https://news.mail.ru/politics/43345614/',
#   'date_of_publication': ['2020-09-13T18:17:51+03:00'],
#   'news_name': 'Александр Дрозденко оценил ход выборов в Ленобласти',
#   'news_source_link': 'https://kommersant.ru',
#   'news_source_name': 'Коммерсантъ'},
#  {'news_link': 'https://news.mail.ru/politics/43339945/',
#   'date_of_publication': ['2020-09-13T02:16:18+03:00'],
#   'news_name': 'В России начался единый день голосования',
#   'news_source_link': 'https://life.ru/',
#   'news_source_name': 'Life.ru'},
#  {'news_link': 'https://news.mail.ru/politics/43347414/',
#   'date_of_publication': ['2020-09-13T20:52:17+03:00'],
#   'news_name': 'Александр Дрозденко поблагодарил ленинградцев за участие в выборах',
#   'news_source_link': 'https://ivbg.ru/',
#   'news_source_name': 'ivbg.ru'},
#  {'news_link': 'https://news.mail.ru/politics/43317486/',
#   'date_of_publication': ['2020-09-11T10:12:47+03:00'],
#   'news_name': '2,5 или 30 тыс. рублей. Каким будет гарантированный базовый доход в России',
#   'news_source_link': 'https://life.ru/',
#   'news_source_name': 'Life.ru'},
#  {'news_link': 'https://news.mail.ru/politics/43346095/',
#   'date_of_publication': ['2020-09-13T18:47:59+03:00'],
#   'news_name': 'МВД не выявило нарушений, которые могли бы повлиять на итоги выборов',
#   'news_source_link': 'http://www.tass.ru/',
#   'news_source_name': 'ТАСС'},
#  {'news_link': 'https://news.mail.ru/politics/43343536/',
#   'date_of_publication': ['2020-09-13T13:17:25+03:00'],
#   'news_name': 'Белорусские хакеры пригрозили Лукашенко обрушением налоговой системы',
#   'news_source_link': 'https://lenta.ru/',
#   'news_source_name': 'Lenta.Ru'},
#  {'news_link': 'https://news.mail.ru/politics/43325334/',
#   'date_of_publication': ['2020-09-11T14:20:54+03:00'],
#   'news_name': 'В Германии могут ввести феминитивы в армии',
#   'news_source_link': 'http://www.ria.ru',
#   'news_source_name': 'РИА Новости'},
#  {'news_link': 'https://news.mail.ru/politics/43336809/',
#   'date_of_publication': ['2020-09-12T15:59:14+03:00'],
#   'news_name': 'Белорусские силовики задержали около 30 участниц демонстрации в Минске',
#   'news_source_link': 'http://www.tass.ru/',
#   'news_source_name': 'ТАСС'},
#  {'news_link': 'https://news.mail.ru/politics/43331985/',
#   'date_of_publication': ['2020-09-12T04:06:25+03:00'],
#   'news_name': 'Власти США получили список предполагаемых участников так называемого проекта «Лахта»',
#   'news_source_link': 'http://www.tass.ru/',
#   'news_source_name': 'ТАСС'},
#  {'news_link': 'https://news.mail.ru/politics/43338974/',
#   'date_of_publication': ['2020-09-12T22:22:55+03:00'],
#   'news_name': 'Белоруссия вернула войска от границы с ЕС',
#   'news_source_link': 'https://www.rbc.ru/',
#   'news_source_name': 'РБК'},
#  {'news_link': 'https://news.mail.ru/politics/43346061/',
#   'date_of_publication': ['2020-09-13T18:20:01+03:00'],
#   'news_name': 'Протестующие начали постройку баррикад в Минске',
#   'news_source_link': 'http://iz.ru/',
#   'news_source_name': 'Известия'},
#  {'news_link': 'https://news.mail.ru/politics/43332454/',
#   'date_of_publication': ['2020-09-12T05:17:33+03:00'],
#   'news_name': 'Россия направила США ноту с просьбой о заключенном летчике',
#   'news_source_link': 'https://lenta.ru/',
#   'news_source_name': 'Lenta.Ru'},
#  {'news_link': 'https://news.mail.ru/politics/43342507/',
#   'date_of_publication': ['2020-09-13T12:17:01+03:00'],
#   'news_name': 'Явка избирателей Ленобласти в 10 часов утра составила 35,9%',
#   'news_source_link': 'https://kommersant.ru',
#   'news_source_name': 'Коммерсантъ'},
#  {'news_link': 'https://news.mail.ru/politics/43341722/',
#   'date_of_publication': ['2020-09-13T09:57:06+03:00'],
#   'news_name': 'Bloomberg узнал прогноз Путина по событиям в Белоруссии',
#   'news_source_link': 'https://www.forbes.ru/',
#   'news_source_name': 'Forbes'},
#  {'news_link': 'https://news.mail.ru/politics/43334583/',
#   'date_of_publication': ['2020-09-12T11:28:59+03:00'],
#   'news_name': 'В США верят, что в Афганистане возможен прочный мир',
#   'news_source_link': 'http://www.tass.ru/',
#   'news_source_name': 'ТАСС'},
#  {'news_link': 'https://news.mail.ru/politics/43322596/',
#   'date_of_publication': ['2020-09-11T12:08:07+03:00'],
#   'news_name': 'Microsoft заявила об атаках российских хакеров на 200 связанных с выборами в США организаций',
#   'news_source_link': 'https://www.forbes.ru/',
#   'news_source_name': 'Forbes'},
#  {'news_link': 'https://news.mail.ru/politics/43326469/',
#   'date_of_publication': ['2020-09-11T15:34:04+03:00'],
#   'news_name': 'Встреча Путина и Лукашенко пройдет в Сочи',
#   'news_source_link': 'http://iz.ru/',
#   'news_source_name': 'Известия'}]

# %%
lenta_politics_news = get_news('lenta.ru', rubric='politics')
lenta_politics_news
# Out:
# [{'news_link': 'https://lenta.ru/news/2020/09/12/mcgregor/',
#   'date_of_publication': ['2020-09-12T19:43:00+03:00'],
#   'news_name': 'Макгрегора арестовали',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/mavzolee/',
#   'date_of_publication': ['2020-09-13T18:45:00+03:00'],
#   'news_name': 'Объяснено возникновение идеи поместить тело Ленина в Мавзолей',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/domoy/',
#   'date_of_publication': ['2020-09-12T21:00:00+03:00'],
#   'news_name': 'Палестина отозвала посла в Бахрейне из-за примирения с Израилем',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/ugroza/',
#   'date_of_publication': ['2020-09-13T14:01:00+03:00'],
#   'news_name': 'Китай признал США главной угрозой международному порядку',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/soyuz/',
#   'date_of_publication': ['2020-09-12T08:58:52+03:00'],
#   'news_name': 'В США увидели угрозу в союзе России и Китая',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/yaroshenko/',
#   'date_of_publication': ['2020-09-12T04:09:22+03:00'],
#   'news_name': 'Россия направила США ноту с просьбой о заключенном летчике',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/udalenie/',
#   'date_of_publication': ['2020-09-12T18:24:00+03:00'],
#   'news_name': 'Москва отреагировала на требование Киева удалить приложения российских СМИ',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/cze_bel/',
#   'date_of_publication': ['2020-09-12T21:48:13+03:00'],
#   'news_name': 'В Чехии заявили об угрозе России для Белоруссии',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/trump/',
#   'date_of_publication': ['2020-09-13T06:03:50+03:00'],
#   'news_name': 'Трамп порадовался соперничеству с Байденом и вспомнил о его лекарствах',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/us/',
#   'date_of_publication': ['2020-09-13T06:37:00+03:00'],
#   'news_name': 'США обеспокоились заходами российских кораблей в порты Кипра',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/spetstekhnika/',
#   'date_of_publication': ['2020-09-13T15:16:00+03:00'],
#   'news_name': 'Протестующие в Минске двинулись к элитному кварталу чиновников',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/nobel/',
#   'date_of_publication': ['2020-09-13T07:16:32+03:00'],
#   'news_name': 'Трамп возмутился из-за игнорирования его номинации на Нобелевскую премию мира',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/lvrv/',
#   'date_of_publication': ['2020-09-12T14:19:00+03:00'],
#   'news_name': 'Лавров пообещал ответить на возможные санкции из-за дела Навального',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/brief/2020/09/02/merkel_navalny/',
#   'date_of_publication': ['2020-09-02T21:14:00+03:00'],
#   'news_name': 'В Германии заявили о следах «Новичка» в организме Навального',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/sp2/',
#   'date_of_publication': ['2020-09-12T13:48:00+03:00'],
#   'news_name': 'Дания выступила за пересмотр отношения к «Северному потоку-2»',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/otnosheniya/',
#   'date_of_publication': ['2020-09-12T07:14:29+03:00'],
#   'news_name': 'Ситуацию с Навальным назвали поводом испортить отношения России и Германии',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/brief/2020/09/07/jokes_on_you/',
#   'date_of_publication': ['2020-09-07T17:03:00+03:00'],
#   'news_name': 'Россия едва не поссорилась с Сербией из-за поста Захаровой',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/voennie/',
#   'date_of_publication': ['2020-09-13T12:06:00+03:00'],
#   'news_name': 'К резиденции Лукашенко стянули бронетехнику',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/razvedka/',
#   'date_of_publication': ['2020-09-13T18:05:00+03:00'],
#   'news_name': 'Российский «Буревестник» напугал Великобританию',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/opinion/',
#   'date_of_publication': ['2020-09-13T16:08:00+03:00'],
#   'news_name': 'Стало известно возможное мнение Путина насчет судьбы Лукашенко',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/articles/2020/09/08/what_now/',
#   'date_of_publication': ['2020-09-08T00:01:00+03:00'],
#   'news_name': '«В интересах Москвы найти того, кто использует яды»',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/gumanitar/',
#   'date_of_publication': ['2020-09-12T14:56:00+03:00'],
#   'news_name': 'Россия снова помогла Северной Корее зерном',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/articles/2020/09/11/suga/',
#   'date_of_publication': ['2020-09-11T00:03:00+03:00'],
#   'news_name': 'Кандидат от народа',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/iran/',
#   'date_of_publication': ['2020-09-13T00:38:57+03:00'],
#   'news_name': 'США осудили казнь иранского борца властями страны',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/usaf/',
#   'date_of_publication': ['2020-09-12T15:40:00+03:00'],
#   'news_name': 'ВВС США назвали место будущей войны',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/11/nov_strngr/',
#   'date_of_publication': ['2020-09-11T19:28:00+03:00'],
#   'news_name': 'Разработчик «Новичка» ответил на заявление о более сильной версии яда',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/11/kremlin/',
#   'date_of_publication': ['2020-09-11T12:53:00+03:00'],
#   'news_name': 'Кремль отреагировал на идею Медведева о раздаче денег россиянам',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'}]

# %%
yandex_politics_news = get_news('yandex.ru', rubric='politics')
yandex_politics_news
# Out:
# [{'news_link': 'https://yandex.ru/news/story/V_Britanii_zayavili_ob_opasnosti_rossijskoj_rakety_Burevestnik--fdaeeef623029fd04a75b4021191354b?lang=ru&rubric=politics&stid=hlprKi5qIanC_5yKNsxL&t=1600020238&tt=true&persistent_id=112335242',
#   'news_name': 'В Британии заявили об опасности российской ракеты «Буревестник»',
#   'date_of_publication': ['2020-09-13 20:38'],
#   'news_source_link': 'https://www.rbc.ru/politics/13/09/2020/5f5e35e89a7947673e94b035?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'РБК'},
#  {'news_link': 'https://yandex.ru/news/story/Ukraina_obyasnila_otkaz_ot_postavok_vody_v_Krym--8c68f662bae0b1c534a0699a898cba4e?lang=ru&rubric=politics&stid=DkBUdq0Sax17Nhfbg-n3&t=1600020238&tt=true&persistent_id=112336874',
#   'news_name': 'Украина объяснила отказ от поставок воды в Крым',
#   'date_of_publication': ['2020-09-13 21:01'],
#   'news_source_link': 'https://www.rbc.ru/rbcfreenews/5f5e32799a7947667fd03ce2?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'РБК'},
#  {'news_link': 'https://yandex.ru/news/story/CIK_nazval_region_s_samoj_vysokoj_yavkoj_na_vyborakh_glav_regionov--3c8130d70598fc01f30d371190aa175a?lang=ru&rubric=politics&stid=e74O4oqhK9PUC7ggTXfM&t=1600020238&tt=true&persistent_id=112278279',
#   'news_name': 'ЦИК назвал регион с самой высокой явкой на выборах глав регионов',
#   'date_of_publication': ['2020-09-13 20:53'],
#   'news_source_link': 'https://ria.ru/20200913/golosovanie-1577181464.html?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'РИА Новости'},
#  {'news_link': 'https://yandex.ru/news/story/Pompeo_vyrazil_bespokojstvo_zakhodom_voennykh_korablej_RF_v_porty_Kipra--8534984fbc026767a2e6836dc265572a?lang=ru&rubric=politics&stid=rHCHlxNuQEi85vXqNCxH&t=1600020238&tt=true&persistent_id=112310564',
#   'news_name': 'Помпео выразил беспокойство заходом военных кораблей РФ в порты Кипра',
#   'date_of_publication': ['2020-09-13 20:26'],
#   'news_source_link': 'https://www.gazeta.ru/army/2020/09/13/13249400.shtml?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'Газета.Ru'},
#  {'news_link': 'https://yandex.ru/news/story/Bloomberg_Putin_ne_verit_chto_oppoziciya_smestit_Lukashenko--df656a4858bb03b193ff098083bf5c46?lang=ru&rubric=politics&stid=QVb5rchEf_UI79cA_dv7&t=1600020238&tt=true&persistent_id=112323242',
#   'news_name': 'Bloomberg: Путин не верит, что оппозиция сместит Лукашенко',
#   'date_of_publication': ['2020-09-13 20:49'],
#   'news_source_link': 'https://www.kommersant.ru/doc/4491546?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'Коммерсантъ'},
#  {'news_link': 'https://yandex.ru/news/story/V_Sevastopole_k_1800_progolosovali_pochti_45_izbiratelej--0608176e79bb37db8337bcf0721faf73?lang=ru&rubric=politics&stid=oLD65xzw92gtL11boG6l&t=1600020238&persistent_id=112252667',
#   'news_name': 'В Севастополе к 18:00 проголосовали почти 45% избирателей',
#   'date_of_publication': ['2020-09-13 20:59'],
#   'news_source_link': 'https://regnum.ru/news/3061921.html?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'REGNUM'},
#  {'news_link': 'https://yandex.ru/news/story/Lavrov_zayavil_o_zhelanii_ES_nakazat_Rossiyu--e30bdadc57062e4bdc0bcdcb71af6342?lang=ru&rubric=politics&stid=BnYoEukSgxCVBTV9bX-J&t=1600020238&tt=true&persistent_id=112336525',
#   'news_name': 'Лавров заявил о желании ЕС «наказать Россию»',
#   'date_of_publication': ['2020-09-13 20:49'],
#   'news_source_link': 'https://iz.ru/1060084/2020-09-13/lavrov-zaiavil-o-zhelanii-es-nakazat-rossiiu?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'Известия'},
#  {'news_link': 'https://yandex.ru/news/story/Daniya_predlozhila_nachat_novoe_obsuzhdenie_po_Severnomu_potoku-2--e155f5125d331cd86f545a8a36bbde48?lang=ru&rubric=politics&stid=CHPh3cA7bLCKqYJ_32ww&t=1600020238&persistent_id=112280908',
#   'news_name': 'Дания предложила начать новое обсуждение по «Северному потоку-2»',
#   'date_of_publication': ['2020-09-13 16:07'],
#   'news_source_link': 'https://www.rbc.ru/politics/12/09/2020/5f5cb2029a794771935cd1ce?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'РБК'},
#  {'news_link': 'https://yandex.ru/news/story/MID_Rossii_otvetil_Apple_na_plany_udalit_prilozheniya_VGTRK_iz_AppStore--6c148a253025b4d80ef8049bdf161183?lang=ru&rubric=politics&stid=YHWM9ifMUJgN6QFFZ8h5&t=1600020238&persistent_id=112293047',
#   'news_name': 'МИД России ответил Apple на планы удалить приложения ВГТРК из AppStore',
#   'date_of_publication': ['2020-09-13 08:43'],
#   'news_source_link': 'https://vesti-k.ru/mid-rossii-otvetil-apple-na-plany-udalit-prilozheniya-vgtrk-iz-appstore/?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'Вести Крым'},
#  {'news_link': 'https://yandex.ru/news/story/Vladimir_Solodov_vyshel_v_lidery_na_vyborakh_gubernatora_Kamchatki--88cbcbf1b4ce86d252c99472494429da?lang=ru&rubric=politics&stid=QxkHgkZEBbHHwv4fzfwb&t=1600020238&tt=true&persistent_id=112333579',
#   'news_name': 'Владимир Солодов вышел в лидеры на выборах губернатора Камчатки',
#   'date_of_publication': ['2020-09-13 20:59'],
#   'news_source_link': 'https://www.rbc.ru/politics/13/09/2020/5f5df0979a79474f8926eec9?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'РБК'},
#  {'news_link': 'https://yandex.ru/news/story/ZHirinovskij_prizval_Rossiyu_izlechitsya_ot_chetyrekh_boleznej--2494d4d56e42ce34aeb7553794a685f1?lang=ru&rubric=politics&stid=N6-y8Ogi7ooJPnHJ9pEh&t=1600020238&persistent_id=112346760',
#   'news_name': 'Жириновский призвал Россию излечиться от четырех болезней',
#   'date_of_publication': ['2020-09-13 20:21'],
#   'news_source_link': 'https://yandex.ru/turbo/u-f.ru/s/news/politics/u25522/2020/09/13/302478?sign=09d889ddf75890445fd68e48acc241706844475085f27d5d8f2cb283ae6839fd%3A1600021169&utm_source=yxnews&utm_medium=desktop&trbsrc=neo-news',
#   'news_source_name': 'Южный Федеральный'},
#  {'news_link': 'https://yandex.ru/news/story/Predsedatel_Mosgorsuda_Egorova_podala_v_otstavku_posle_20_let_sluzhby--06e2d8b4ef1030562faab4caa15da7e9?lang=ru&rubric=politics&stid=GdfhzzznXDqPDN4Xf6Ub&t=1600020238&persistent_id=112221980',
#   'news_name': 'Председатель Мосгорсуда Егорова подала в отставку после 20 лет службы',
#   'date_of_publication': ['2020-09-13 19:46'],
#   'news_source_link': 'https://www.vedomosti.ru/society/news/2020/09/11/839621-glava-mosgorsuda-egorova-podala-v-otstavku-posle-20-let-na-postu-postu?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'Ведомости'},
#  {'news_link': 'https://yandex.ru/news/story/Opublikovany_foto_udara_giperzvukovoj_raketoj_Kinzhal_po_avianoscu--30e4f27bef5b37a5fb9eb0529ec097d3?lang=ru&rubric=politics&stid=mWhtkLP8CCaKXxQ4y-qB&t=1600020238&persistent_id=112312263',
#   'news_name': 'Опубликованы фото удара гиперзвуковой ракетой «Кинжал» по авианосцу',
#   'date_of_publication': ['2020-09-13 15:54'],
#   'news_source_link': 'https://evo-rus.com/avto/exluzive/opublikovany-foto-udara-giperzvukovoj-raketoj-kinzhal-po-avianostsu.html?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'Evo-rus.com'},
#  {'news_link': 'https://yandex.ru/news/story/V_Minske_vmeste_s_marshem_zhenshhin_nachalas_akciya_v_podderzhku_Lukashenko--f70e04dad5e287c57f9fa4426874d548?lang=ru&rubric=politics&stid=QbE8Tm994T2wWWTJKC4w&t=1600020238&persistent_id=112168423',
#   'news_name': 'В Минске вместе с маршем женщин началась акция в поддержку Лукашенко',
#   'date_of_publication': ['2020-09-13 20:16'],
#   'news_source_link': 'https://www.rbc.ru/rbcfreenews/5f5cdc2e9a79478197c3c974?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'РБК'},
#  {'news_link': 'https://yandex.ru/news/story/EHkzit-polly_otdayut_Olegu_Nikolaevu_82_na_vyborakh_glavy_CHuvashii--2dfd51ca311a44235b1bc012f2cfc0df?lang=ru&rubric=politics&stid=n5qeXTrSJWJh&t=1600020238&persistent_id=112404930',
#   'news_name': 'Экзит-поллы отдают Олегу Николаеву 82% на выборах главы Чувашии',
#   'date_of_publication': ['2020-09-13 20:58'],
#   'news_source_link': 'https://pravdapfo.ru/news/98745-ekzit-polly-otdayut-olegu-nikolaevu-82?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'Правда ПФО'}]

# %%
data_insert = mail_politics_news
data_insert.extend(lenta_politics_news)
data_insert.extend(yandex_politics_news)
data_insert
# Out:
# [{'news_link': 'https://news.mail.ru/politics/43337955/',
#   'date_of_publication': ['2020-09-12T22:15:50+03:00'],
#   'news_name': 'Как прошел второй день досрочного голосования в Ленобласти',
#   'news_source_link': 'https://ivbg.ru/',
#   'news_source_name': 'ivbg.ru'},
#  {'news_link': 'https://news.mail.ru/politics/43345991/',
#   'date_of_publication': ['2020-09-13T18:12:19+03:00'],
#   'news_name': 'Основная масса протестующих в Минске собралась в районе Дрозды',
#   'news_source_link': 'http://www.tass.ru/',
#   'news_source_name': 'ТАСС'},
#  {'news_link': 'https://news.mail.ru/politics/43345119/',
#   'date_of_publication': ['2020-09-13T16:18:46+03:00'],
#   'news_name': 'Канцлер Австрии сообщил о начале второй волны коронавируса в стране',
#   'news_source_link': 'http://www.kommersant.ru',
#   'news_source_name': 'Коммерсантъ'},
#  {'news_link': 'https://news.mail.ru/politics/43328260/',
#   'date_of_publication': ['2020-09-11T17:27:40+03:00'],
#   'news_name': 'Правительство переименовало Минкомсвязи',
#   'news_source_link': 'http://www.interfax.ru/',
#   'news_source_name': 'Интерфакс'},
#  {'news_link': 'https://news.mail.ru/politics/43331014/',
#   'date_of_publication': ['2020-09-11T21:44:35+03:00'],
#   'news_name': 'Козак рассказал об итогах встречи советников «нормандской четверки»',
#   'news_source_link': 'http://www.ria.ru',
#   'news_source_name': 'РИА Новости'},
#  {'news_link': 'https://news.mail.ru/politics/43343261/',
#   'date_of_publication': ['2020-09-13T12:47:53+03:00'],
#   'news_name': 'Названы регионы России с самой высокой и низкой явкой на выборах',
#   'news_source_link': 'https://lenta.ru/',
#   'news_source_name': 'Lenta.Ru'},
#  {'news_link': 'https://news.mail.ru/politics/43343286/',
#   'date_of_publication': ['2020-09-13T14:31:09+03:00'],
#   'news_name': 'Видео: Александр Дрозденко принял участие в едином дне голосования',
#   'news_source_link': 'https://ivbg.ru/',
#   'news_source_name': 'ivbg.ru'},
#  {'news_link': 'https://news.mail.ru/politics/43342478/',
#   'date_of_publication': ['2020-09-13T11:18:56+03:00'],
#   'news_name': 'Губернатором НАО стал Юрий Бездудный',
#   'news_source_link': 'http://www.kommersant.ru',
#   'news_source_name': 'Коммерсантъ'},
#  {'news_link': 'https://news.mail.ru/politics/43344832/',
#   'date_of_publication': ['2020-09-13T15:44:24+03:00'],
#   'news_name': 'МВД Белоруссии сообщило о задержании 250 человек в Минске',
#   'news_source_link': 'http://www.ria.ru',
#   'news_source_name': 'РИА Новости'},
#  {'news_link': 'https://news.mail.ru/politics/43341701/',
#   'date_of_publication': ['2020-09-13T10:04:08+03:00'],
#   'news_name': 'В России проходит единый день голосования',
#   'news_source_link': 'https://rns.online/',
#   'news_source_name': 'RNS'},
#  {'news_link': 'https://news.mail.ru/politics/43335429/',
#   'date_of_publication': ['2020-09-12T13:06:19+03:00'],
#   'news_name': 'Белорусскую оппозиционерку Колесникову перевели в следственную тюрьму',
#   'news_source_link': 'https://life.ru/',
#   'news_source_name': 'Life.ru'},
#  {'news_link': 'https://news.mail.ru/politics/43343695/',
#   'date_of_publication': ['2020-09-13T13:32:46+03:00'],
#   'news_name': 'Памфилова заявила о возможности для ЦИК «поучиться» у Казахстана',
#   'news_source_link': 'https://www.rbc.ru/',
#   'news_source_name': 'РБК'},
#  {'news_link': 'https://news.mail.ru/politics/43345614/',
#   'date_of_publication': ['2020-09-13T18:17:51+03:00'],
#   'news_name': 'Александр Дрозденко оценил ход выборов в Ленобласти',
#   'news_source_link': 'https://kommersant.ru',
#   'news_source_name': 'Коммерсантъ'},
#  {'news_link': 'https://news.mail.ru/politics/43339945/',
#   'date_of_publication': ['2020-09-13T02:16:18+03:00'],
#   'news_name': 'В России начался единый день голосования',
#   'news_source_link': 'https://life.ru/',
#   'news_source_name': 'Life.ru'},
#  {'news_link': 'https://news.mail.ru/politics/43347414/',
#   'date_of_publication': ['2020-09-13T20:52:17+03:00'],
#   'news_name': 'Александр Дрозденко поблагодарил ленинградцев за участие в выборах',
#   'news_source_link': 'https://ivbg.ru/',
#   'news_source_name': 'ivbg.ru'},
#  {'news_link': 'https://news.mail.ru/politics/43317486/',
#   'date_of_publication': ['2020-09-11T10:12:47+03:00'],
#   'news_name': '2,5 или 30 тыс. рублей. Каким будет гарантированный базовый доход в России',
#   'news_source_link': 'https://life.ru/',
#   'news_source_name': 'Life.ru'},
#  {'news_link': 'https://news.mail.ru/politics/43346095/',
#   'date_of_publication': ['2020-09-13T18:47:59+03:00'],
#   'news_name': 'МВД не выявило нарушений, которые могли бы повлиять на итоги выборов',
#   'news_source_link': 'http://www.tass.ru/',
#   'news_source_name': 'ТАСС'},
#  {'news_link': 'https://news.mail.ru/politics/43343536/',
#   'date_of_publication': ['2020-09-13T13:17:25+03:00'],
#   'news_name': 'Белорусские хакеры пригрозили Лукашенко обрушением налоговой системы',
#   'news_source_link': 'https://lenta.ru/',
#   'news_source_name': 'Lenta.Ru'},
#  {'news_link': 'https://news.mail.ru/politics/43325334/',
#   'date_of_publication': ['2020-09-11T14:20:54+03:00'],
#   'news_name': 'В Германии могут ввести феминитивы в армии',
#   'news_source_link': 'http://www.ria.ru',
#   'news_source_name': 'РИА Новости'},
#  {'news_link': 'https://news.mail.ru/politics/43336809/',
#   'date_of_publication': ['2020-09-12T15:59:14+03:00'],
#   'news_name': 'Белорусские силовики задержали около 30 участниц демонстрации в Минске',
#   'news_source_link': 'http://www.tass.ru/',
#   'news_source_name': 'ТАСС'},
#  {'news_link': 'https://news.mail.ru/politics/43331985/',
#   'date_of_publication': ['2020-09-12T04:06:25+03:00'],
#   'news_name': 'Власти США получили список предполагаемых участников так называемого проекта «Лахта»',
#   'news_source_link': 'http://www.tass.ru/',
#   'news_source_name': 'ТАСС'},
#  {'news_link': 'https://news.mail.ru/politics/43338974/',
#   'date_of_publication': ['2020-09-12T22:22:55+03:00'],
#   'news_name': 'Белоруссия вернула войска от границы с ЕС',
#   'news_source_link': 'https://www.rbc.ru/',
#   'news_source_name': 'РБК'},
#  {'news_link': 'https://news.mail.ru/politics/43346061/',
#   'date_of_publication': ['2020-09-13T18:20:01+03:00'],
#   'news_name': 'Протестующие начали постройку баррикад в Минске',
#   'news_source_link': 'http://iz.ru/',
#   'news_source_name': 'Известия'},
#  {'news_link': 'https://news.mail.ru/politics/43332454/',
#   'date_of_publication': ['2020-09-12T05:17:33+03:00'],
#   'news_name': 'Россия направила США ноту с просьбой о заключенном летчике',
#   'news_source_link': 'https://lenta.ru/',
#   'news_source_name': 'Lenta.Ru'},
#  {'news_link': 'https://news.mail.ru/politics/43342507/',
#   'date_of_publication': ['2020-09-13T12:17:01+03:00'],
#   'news_name': 'Явка избирателей Ленобласти в 10 часов утра составила 35,9%',
#   'news_source_link': 'https://kommersant.ru',
#   'news_source_name': 'Коммерсантъ'},
#  {'news_link': 'https://news.mail.ru/politics/43341722/',
#   'date_of_publication': ['2020-09-13T09:57:06+03:00'],
#   'news_name': 'Bloomberg узнал прогноз Путина по событиям в Белоруссии',
#   'news_source_link': 'https://www.forbes.ru/',
#   'news_source_name': 'Forbes'},
#  {'news_link': 'https://news.mail.ru/politics/43334583/',
#   'date_of_publication': ['2020-09-12T11:28:59+03:00'],
#   'news_name': 'В США верят, что в Афганистане возможен прочный мир',
#   'news_source_link': 'http://www.tass.ru/',
#   'news_source_name': 'ТАСС'},
#  {'news_link': 'https://news.mail.ru/politics/43322596/',
#   'date_of_publication': ['2020-09-11T12:08:07+03:00'],
#   'news_name': 'Microsoft заявила об атаках российских хакеров на 200 связанных с выборами в США организаций',
#   'news_source_link': 'https://www.forbes.ru/',
#   'news_source_name': 'Forbes'},
#  {'news_link': 'https://news.mail.ru/politics/43326469/',
#   'date_of_publication': ['2020-09-11T15:34:04+03:00'],
#   'news_name': 'Встреча Путина и Лукашенко пройдет в Сочи',
#   'news_source_link': 'http://iz.ru/',
#   'news_source_name': 'Известия'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/mcgregor/',
#   'date_of_publication': ['2020-09-12T19:43:00+03:00'],
#   'news_name': 'Макгрегора арестовали',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/mavzolee/',
#   'date_of_publication': ['2020-09-13T18:45:00+03:00'],
#   'news_name': 'Объяснено возникновение идеи поместить тело Ленина в Мавзолей',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/domoy/',
#   'date_of_publication': ['2020-09-12T21:00:00+03:00'],
#   'news_name': 'Палестина отозвала посла в Бахрейне из-за примирения с Израилем',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/ugroza/',
#   'date_of_publication': ['2020-09-13T14:01:00+03:00'],
#   'news_name': 'Китай признал США главной угрозой международному порядку',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/soyuz/',
#   'date_of_publication': ['2020-09-12T08:58:52+03:00'],
#   'news_name': 'В США увидели угрозу в союзе России и Китая',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/yaroshenko/',
#   'date_of_publication': ['2020-09-12T04:09:22+03:00'],
#   'news_name': 'Россия направила США ноту с просьбой о заключенном летчике',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/udalenie/',
#   'date_of_publication': ['2020-09-12T18:24:00+03:00'],
#   'news_name': 'Москва отреагировала на требование Киева удалить приложения российских СМИ',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/cze_bel/',
#   'date_of_publication': ['2020-09-12T21:48:13+03:00'],
#   'news_name': 'В Чехии заявили об угрозе России для Белоруссии',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/trump/',
#   'date_of_publication': ['2020-09-13T06:03:50+03:00'],
#   'news_name': 'Трамп порадовался соперничеству с Байденом и вспомнил о его лекарствах',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/us/',
#   'date_of_publication': ['2020-09-13T06:37:00+03:00'],
#   'news_name': 'США обеспокоились заходами российских кораблей в порты Кипра',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/spetstekhnika/',
#   'date_of_publication': ['2020-09-13T15:16:00+03:00'],
#   'news_name': 'Протестующие в Минске двинулись к элитному кварталу чиновников',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/nobel/',
#   'date_of_publication': ['2020-09-13T07:16:32+03:00'],
#   'news_name': 'Трамп возмутился из-за игнорирования его номинации на Нобелевскую премию мира',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/lvrv/',
#   'date_of_publication': ['2020-09-12T14:19:00+03:00'],
#   'news_name': 'Лавров пообещал ответить на возможные санкции из-за дела Навального',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/brief/2020/09/02/merkel_navalny/',
#   'date_of_publication': ['2020-09-02T21:14:00+03:00'],
#   'news_name': 'В Германии заявили о следах «Новичка» в организме Навального',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/sp2/',
#   'date_of_publication': ['2020-09-12T13:48:00+03:00'],
#   'news_name': 'Дания выступила за пересмотр отношения к «Северному потоку-2»',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/otnosheniya/',
#   'date_of_publication': ['2020-09-12T07:14:29+03:00'],
#   'news_name': 'Ситуацию с Навальным назвали поводом испортить отношения России и Германии',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/brief/2020/09/07/jokes_on_you/',
#   'date_of_publication': ['2020-09-07T17:03:00+03:00'],
#   'news_name': 'Россия едва не поссорилась с Сербией из-за поста Захаровой',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/voennie/',
#   'date_of_publication': ['2020-09-13T12:06:00+03:00'],
#   'news_name': 'К резиденции Лукашенко стянули бронетехнику',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/razvedka/',
#   'date_of_publication': ['2020-09-13T18:05:00+03:00'],
#   'news_name': 'Российский «Буревестник» напугал Великобританию',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/opinion/',
#   'date_of_publication': ['2020-09-13T16:08:00+03:00'],
#   'news_name': 'Стало известно возможное мнение Путина насчет судьбы Лукашенко',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/articles/2020/09/08/what_now/',
#   'date_of_publication': ['2020-09-08T00:01:00+03:00'],
#   'news_name': '«В интересах Москвы найти того, кто использует яды»',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/gumanitar/',
#   'date_of_publication': ['2020-09-12T14:56:00+03:00'],
#   'news_name': 'Россия снова помогла Северной Корее зерном',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/articles/2020/09/11/suga/',
#   'date_of_publication': ['2020-09-11T00:03:00+03:00'],
#   'news_name': 'Кандидат от народа',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/13/iran/',
#   'date_of_publication': ['2020-09-13T00:38:57+03:00'],
#   'news_name': 'США осудили казнь иранского борца властями страны',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/12/usaf/',
#   'date_of_publication': ['2020-09-12T15:40:00+03:00'],
#   'news_name': 'ВВС США назвали место будущей войны',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/11/nov_strngr/',
#   'date_of_publication': ['2020-09-11T19:28:00+03:00'],
#   'news_name': 'Разработчик «Новичка» ответил на заявление о более сильной версии яда',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://lenta.ru/news/2020/09/11/kremlin/',
#   'date_of_publication': ['2020-09-11T12:53:00+03:00'],
#   'news_name': 'Кремль отреагировал на идею Медведева о раздаче денег россиянам',
#   'news_source_link': 'https://lenta.ru',
#   'news_source_name': 'Lenta.ru («Лента.ру»)'},
#  {'news_link': 'https://yandex.ru/news/story/V_Britanii_zayavili_ob_opasnosti_rossijskoj_rakety_Burevestnik--fdaeeef623029fd04a75b4021191354b?lang=ru&rubric=politics&stid=hlprKi5qIanC_5yKNsxL&t=1600020238&tt=true&persistent_id=112335242',
#   'news_name': 'В Британии заявили об опасности российской ракеты «Буревестник»',
#   'date_of_publication': ['2020-09-13 20:38'],
#   'news_source_link': 'https://www.rbc.ru/politics/13/09/2020/5f5e35e89a7947673e94b035?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'РБК'},
#  {'news_link': 'https://yandex.ru/news/story/Ukraina_obyasnila_otkaz_ot_postavok_vody_v_Krym--8c68f662bae0b1c534a0699a898cba4e?lang=ru&rubric=politics&stid=DkBUdq0Sax17Nhfbg-n3&t=1600020238&tt=true&persistent_id=112336874',
#   'news_name': 'Украина объяснила отказ от поставок воды в Крым',
#   'date_of_publication': ['2020-09-13 21:01'],
#   'news_source_link': 'https://www.rbc.ru/rbcfreenews/5f5e32799a7947667fd03ce2?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'РБК'},
#  {'news_link': 'https://yandex.ru/news/story/CIK_nazval_region_s_samoj_vysokoj_yavkoj_na_vyborakh_glav_regionov--3c8130d70598fc01f30d371190aa175a?lang=ru&rubric=politics&stid=e74O4oqhK9PUC7ggTXfM&t=1600020238&tt=true&persistent_id=112278279',
#   'news_name': 'ЦИК назвал регион с самой высокой явкой на выборах глав регионов',
#   'date_of_publication': ['2020-09-13 20:53'],
#   'news_source_link': 'https://ria.ru/20200913/golosovanie-1577181464.html?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'РИА Новости'},
#  {'news_link': 'https://yandex.ru/news/story/Pompeo_vyrazil_bespokojstvo_zakhodom_voennykh_korablej_RF_v_porty_Kipra--8534984fbc026767a2e6836dc265572a?lang=ru&rubric=politics&stid=rHCHlxNuQEi85vXqNCxH&t=1600020238&tt=true&persistent_id=112310564',
#   'news_name': 'Помпео выразил беспокойство заходом военных кораблей РФ в порты Кипра',
#   'date_of_publication': ['2020-09-13 20:26'],
#   'news_source_link': 'https://www.gazeta.ru/army/2020/09/13/13249400.shtml?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'Газета.Ru'},
#  {'news_link': 'https://yandex.ru/news/story/Bloomberg_Putin_ne_verit_chto_oppoziciya_smestit_Lukashenko--df656a4858bb03b193ff098083bf5c46?lang=ru&rubric=politics&stid=QVb5rchEf_UI79cA_dv7&t=1600020238&tt=true&persistent_id=112323242',
#   'news_name': 'Bloomberg: Путин не верит, что оппозиция сместит Лукашенко',
#   'date_of_publication': ['2020-09-13 20:49'],
#   'news_source_link': 'https://www.kommersant.ru/doc/4491546?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'Коммерсантъ'},
#  {'news_link': 'https://yandex.ru/news/story/V_Sevastopole_k_1800_progolosovali_pochti_45_izbiratelej--0608176e79bb37db8337bcf0721faf73?lang=ru&rubric=politics&stid=oLD65xzw92gtL11boG6l&t=1600020238&persistent_id=112252667',
#   'news_name': 'В Севастополе к 18:00 проголосовали почти 45% избирателей',
#   'date_of_publication': ['2020-09-13 20:59'],
#   'news_source_link': 'https://regnum.ru/news/3061921.html?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'REGNUM'},
#  {'news_link': 'https://yandex.ru/news/story/Lavrov_zayavil_o_zhelanii_ES_nakazat_Rossiyu--e30bdadc57062e4bdc0bcdcb71af6342?lang=ru&rubric=politics&stid=BnYoEukSgxCVBTV9bX-J&t=1600020238&tt=true&persistent_id=112336525',
#   'news_name': 'Лавров заявил о желании ЕС «наказать Россию»',
#   'date_of_publication': ['2020-09-13 20:49'],
#   'news_source_link': 'https://iz.ru/1060084/2020-09-13/lavrov-zaiavil-o-zhelanii-es-nakazat-rossiiu?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'Известия'},
#  {'news_link': 'https://yandex.ru/news/story/Daniya_predlozhila_nachat_novoe_obsuzhdenie_po_Severnomu_potoku-2--e155f5125d331cd86f545a8a36bbde48?lang=ru&rubric=politics&stid=CHPh3cA7bLCKqYJ_32ww&t=1600020238&persistent_id=112280908',
#   'news_name': 'Дания предложила начать новое обсуждение по «Северному потоку-2»',
#   'date_of_publication': ['2020-09-13 16:07'],
#   'news_source_link': 'https://www.rbc.ru/politics/12/09/2020/5f5cb2029a794771935cd1ce?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'РБК'},
#  {'news_link': 'https://yandex.ru/news/story/MID_Rossii_otvetil_Apple_na_plany_udalit_prilozheniya_VGTRK_iz_AppStore--6c148a253025b4d80ef8049bdf161183?lang=ru&rubric=politics&stid=YHWM9ifMUJgN6QFFZ8h5&t=1600020238&persistent_id=112293047',
#   'news_name': 'МИД России ответил Apple на планы удалить приложения ВГТРК из AppStore',
#   'date_of_publication': ['2020-09-13 08:43'],
#   'news_source_link': 'https://vesti-k.ru/mid-rossii-otvetil-apple-na-plany-udalit-prilozheniya-vgtrk-iz-appstore/?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'Вести Крым'},
#  {'news_link': 'https://yandex.ru/news/story/Vladimir_Solodov_vyshel_v_lidery_na_vyborakh_gubernatora_Kamchatki--88cbcbf1b4ce86d252c99472494429da?lang=ru&rubric=politics&stid=QxkHgkZEBbHHwv4fzfwb&t=1600020238&tt=true&persistent_id=112333579',
#   'news_name': 'Владимир Солодов вышел в лидеры на выборах губернатора Камчатки',
#   'date_of_publication': ['2020-09-13 20:59'],
#   'news_source_link': 'https://www.rbc.ru/politics/13/09/2020/5f5df0979a79474f8926eec9?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'РБК'},
#  {'news_link': 'https://yandex.ru/news/story/ZHirinovskij_prizval_Rossiyu_izlechitsya_ot_chetyrekh_boleznej--2494d4d56e42ce34aeb7553794a685f1?lang=ru&rubric=politics&stid=N6-y8Ogi7ooJPnHJ9pEh&t=1600020238&persistent_id=112346760',
#   'news_name': 'Жириновский призвал Россию излечиться от четырех болезней',
#   'date_of_publication': ['2020-09-13 20:21'],
#   'news_source_link': 'https://yandex.ru/turbo/u-f.ru/s/news/politics/u25522/2020/09/13/302478?sign=09d889ddf75890445fd68e48acc241706844475085f27d5d8f2cb283ae6839fd%3A1600021169&utm_source=yxnews&utm_medium=desktop&trbsrc=neo-news',
#   'news_source_name': 'Южный Федеральный'},
#  {'news_link': 'https://yandex.ru/news/story/Predsedatel_Mosgorsuda_Egorova_podala_v_otstavku_posle_20_let_sluzhby--06e2d8b4ef1030562faab4caa15da7e9?lang=ru&rubric=politics&stid=GdfhzzznXDqPDN4Xf6Ub&t=1600020238&persistent_id=112221980',
#   'news_name': 'Председатель Мосгорсуда Егорова подала в отставку после 20 лет службы',
#   'date_of_publication': ['2020-09-13 19:46'],
#   'news_source_link': 'https://www.vedomosti.ru/society/news/2020/09/11/839621-glava-mosgorsuda-egorova-podala-v-otstavku-posle-20-let-na-postu-postu?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'Ведомости'},
#  {'news_link': 'https://yandex.ru/news/story/Opublikovany_foto_udara_giperzvukovoj_raketoj_Kinzhal_po_avianoscu--30e4f27bef5b37a5fb9eb0529ec097d3?lang=ru&rubric=politics&stid=mWhtkLP8CCaKXxQ4y-qB&t=1600020238&persistent_id=112312263',
#   'news_name': 'Опубликованы фото удара гиперзвуковой ракетой «Кинжал» по авианосцу',
#   'date_of_publication': ['2020-09-13 15:54'],
#   'news_source_link': 'https://evo-rus.com/avto/exluzive/opublikovany-foto-udara-giperzvukovoj-raketoj-kinzhal-po-avianostsu.html?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'Evo-rus.com'},
#  {'news_link': 'https://yandex.ru/news/story/V_Minske_vmeste_s_marshem_zhenshhin_nachalas_akciya_v_podderzhku_Lukashenko--f70e04dad5e287c57f9fa4426874d548?lang=ru&rubric=politics&stid=QbE8Tm994T2wWWTJKC4w&t=1600020238&persistent_id=112168423',
#   'news_name': 'В Минске вместе с маршем женщин началась акция в поддержку Лукашенко',
#   'date_of_publication': ['2020-09-13 20:16'],
#   'news_source_link': 'https://www.rbc.ru/rbcfreenews/5f5cdc2e9a79478197c3c974?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'РБК'},
#  {'news_link': 'https://yandex.ru/news/story/EHkzit-polly_otdayut_Olegu_Nikolaevu_82_na_vyborakh_glavy_CHuvashii--2dfd51ca311a44235b1bc012f2cfc0df?lang=ru&rubric=politics&stid=n5qeXTrSJWJh&t=1600020238&persistent_id=112404930',
#   'news_name': 'Экзит-поллы отдают Олегу Николаеву 82% на выборах главы Чувашии',
#   'date_of_publication': ['2020-09-13 20:58'],
#   'news_source_link': 'https://pravdapfo.ru/news/98745-ekzit-polly-otdayut-olegu-nikolaevu-82?utm_source=yxnews&utm_medium=desktop',
#   'news_source_name': 'Правда ПФО'}]

# %%
len(data_insert)
# Out:
# 71

# %%
client = MongoClient('127.0.0.1:27017',
                     username='admin_news',
                     password='password_db',
                     authSource='news_db',
                     authMechanism='SCRAM-SHA-1')


db = client['news_db']
collection = db.news

count = 0
for item_news in data_insert:
    try:
        collection.insert_one(item_news)
        count += 1
    except errors.DuplicateKeyError:
        print("Errdor DuplicateKeyError")

count
# Out:
# 71
